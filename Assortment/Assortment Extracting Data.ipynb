# %%
f_path = 'C:\\Users\\Ali Salem\\Desktop\\App_Update\\static/files\\parameters.xlsx'
slides_name = ['SKU Share By Brand', 'SKU Share by Manuf', 'Cumulative Product Share', 'Top 50% cumulative share', 'Brand Cumulative Product Share', 'Top 20 cumulative share', 'SKU Productivity Analysis with TM%', 'SKU Productivity Analysis with WD', 'Fair Share', 'SKU Share By Brand with no client']

# %%
import os
# %run "{os.path.dirname(os.getcwd())}\general_functions\generalFunctions.ipynb" #container

# %run "{os.path.dirname(os.getcwd())}\general_functions\Extracting Data Functions.ipynb" # container

# %%
filename = 'parameters.xlsx'

# Get the current working directory
current_dir = os.path.dirname(os.getcwd())

# Construct the full path to the file
f_path = os.path.join(current_dir, filename)
print(f_path)
#xls = pd.ExcelFile(f_path)
parm = pd.read_excel(f_path, sheet_name='Assortment')
fields = dict(zip(parm['Field'],parm['Value']))
# Out:
# c:\Users\Ali Salem\Desktop\App_Update\parameters.xlsx

# %%
import time
import adodbapi
import pandas as pd
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
start_time = time.time()

# %%
server = "powerbi://api.powerbi.com/v1.0/myorg/"+ fields['server']
dataset_name = fields['f_name']
f_name = os.getcwd()+"/"+fields['f_name']+".xlsx"
conn_str = f"Provider=MSOLAP.8;Data Source={server};Initial Catalog={dataset_name};Timeout=600;"


ManufOrTopC = fields['ManufOrTopC']
BrandOrTopB = fields['BrandOrTopB']
prodORitem=fields["prodORitem"]

client_manuf = list(set(fields['client_manuf'].split(','))-set(['']))
client_brands = list(set(fields['client_brands'].split(','))-set(['']))

decimals = fields['decimals']
sign = fields['sign']
currency = fields['currency']
currency = ' '+ currency if sign.lower() == 'after' else  currency + ' ' 

categories = list(set(fields['categories'].split(','))-set(['']))
sectors=list(set(fields['sectors'].split(','))-set(['']))
segments=list(set(fields['segments'].split(','))-set(['']))
subsegments=list(set(fields['subsegments'].split(','))-set(['']))
subcategories=list(set(fields['subcategories'].split(','))-set(['']))

national=fields['national']
customareas=fields['customareas']
areas = list(set(fields['areas'].split(','))-set(['']))+[customareas]

regions_RET = list(set(fields['regions_RET'].split(','))-set(['']))
channels_RET = list(set(fields['channels_RET'].split(','))-set(['']))
market_RET=list(set(fields['market_RET'].split(','))-set(['']))

regions_CHAN=list(set(fields['regions_CHAN'].split(','))-set(['']))
channels_CHAN=list(set(fields['channels_CHAN'].split(','))-set(['']))
market_CHAN=list(set(fields['market_CHAN'].split(','))-set(['']))

regions_CUST=list(set(fields['regions_CUST'].split(','))-set(['']))
channels_CUST=list(set(fields['channels_CUST'].split(','))-set(['']))
market_CUST=list(set(fields['market_CUST'].split(','))-set(['']))

data_source=fields['data_source']
years=list(set(fields['years'].split(','))-set(['']))
years = {int(y) for y in fields['years'].split(',') if y}
end_date=fields['end_date']
unit=fields['unit']
unitDeviation=fields['unitDeviation']
OpenEditData=fields['OpenEditData']

valueToReplace=fields['valueToReplace'] if not np.nan else {}
client_brands_competitor = list(set(fields['client_brands_competitor'].split(','))-set(['']))

past_12_months = pd.date_range(end=end_date, periods=12, freq='ME').strftime('%b-%y').tolist()
p12m_dax = "{" + ", ".join(f'"{date}"' for date in past_12_months) + "}"
regions = regions_RET + regions_CHAN + regions_CUST
channels = channels_RET + channels_CHAN + channels_CUST
markets = market_RET + market_CHAN + market_CUST

entity_hierarchy = [
    ("Region", regions),
    ("Channel", channels),
    ("Market", markets)
]
hierarchy_levels = [
    ("Category", categories),
    ("Sector", sectors),
    ("Segment", segments),
    ("SubSegment", subsegments),
    ("SubCategory", subcategories)
]

client_brands,ManufOrTopC,decimals,sign,currency,prodORitem,categories
# Out:
# (['Isana Ecb'], 'Top Companies', 2, 'After', ' €', 'Item', ['Female Shaving'])

# %%
path=os.path.join(os.getcwd(),"Assortment Datasets Test")

# %%
# ManufOrTopC ="Top Companies" #Manufacturer or Top Companies
# BrandOrTopB= "Top Brands" #Brand or Top Brands
# prodORitem = "SKU"

# client_manuf =["Pbg"]#["Handel"]#
# client_brands = ["Schick","Equate","Cremo"]#["Handel Eigenmarke"]#

# decimals = 2
# sign = "Before"
# currency = '$ '
# currency = ' '+ currency if sign.lower() == 'after' else  currency + ' '

# categories =["Manual Shave Men"]
# sectors = ["System","Disposables"]
# segments = ["Razors","Refills","Disposables"]
# subsegments= []
# subcategories= []

# national = False
# customareas= "REGIONS"
# areas = ["RETAILER",f'{customareas}']
 
# regions_RET  = []
# channels_RET = ["Walmart","Bj's Corp","Sam's Corp"]
# market_RET = ["Walmart Div1 Corp","Walmart Nm Corp","Walmart Sc Corp"]
 
# regions_CHAN = []
# channels_CHAN = []
# market_CHAN = []
 
# regions_CUST = []
# channels_CUST = ["Walmart East","Walmart North","Walmart Southeast","Walmart Southwest","Walmart West"]
# market_CUST = []

# data_source = "DATA SOURCE: Trade Panel/Retailer Data | Ending March  2025"
# years = ['2023', '2024','2025']
# end_date = "2025-04-01"
# unit = "‘000000s"
# unitDeviation = 1000000
# valueToReplace = {}
# past_12_months = pd.date_range(end=end_date, periods=12, freq='ME').strftime('%b-%y').tolist()
# regions = regions_RET + regions_CHAN + regions_CUST
# channels = channels_RET + channels_CHAN + channels_CUST
# markets = market_RET + market_CHAN + market_CUST

# entity_hierarchy = [
#     ("Region", regions),
#     ("Channel", channels),
#     ("Market", markets)
# ]
# hierarchy_levels = [
#     ("Category", categories),
#     ("Sector", sectors),
#     ("Segment", segments),
#     ("SubSegment", subsegments),
#     ("SubCategory", subcategories)
# ]
# server = "powerbi://api.powerbi.com/v1.0/myorg/Edgewell"
# dataset_name = "Edgewell US Male Dataset"
# conn_str = f"Provider=MSOLAP.8;Data Source={server};Initial Catalog={dataset_name};Timeout=600;"


# path=os.path.join(os.getcwd(),"Assortment Datasets NewEX")

# # Format months for DAX
# p12m_dax = "{" + ", ".join(f'"{date}"' for date in past_12_months) + "}"

# %%
# Function to execute DAX queries
def execute_dax_query(BrandorManuf,entity_name, area, hierby, entity_type):
    outputdic = {}
    dax_query = f"""
    EVALUATE
    CALCULATETABLE(
        SUMMARIZE(
            Products,
            Products[{BrandorManuf}],   
            "Value Share", IF(ISBLANK([Value Share]),0,[Value Share]),
            "SKU Share", IF(ISBLANK([SKU Share]),0,[SKU Share])
        ),
        Products[{hierby}] = "{entity_type}",
        TREATAS(
            {p12m_dax},
            Calendar[MonthYear]
        ),
        TREATAS(
            {{"{entity_name}"}},
            Market[{area}]
        ),
        FILTER(
            'Scope', 
            'Scope'[Scope] = "{hierby}"   
        )
    )   
    """
    try:
        with adodbapi.connect(conn_str) as conn:
            with conn.cursor() as cursor:
                cursor.execute(dax_query)
                columns = [desc[0] for desc in cursor.description]
                data = cursor.fetchall()
                
                df = pd.DataFrame(data, columns=columns)
                df.columns = df.columns.str.replace(r'.*\[|\]', '', regex=True)
                df = df.loc[~(df.select_dtypes(include='number') == 0).all(axis=1)]
                grand_total_values = []
                for col in df.select_dtypes(include='number').columns:
                    if "Price" in col:
                        grand_total_values.append(df[col].mean())  # Take average for price columns
                    else:
                        grand_total_values.append(df[col].sum())   # Take sum for other columns
                grand_total_row = pd.DataFrame([["Grand Total"] + grand_total_values], columns=df.columns)
                df = pd.concat([df, grand_total_row], ignore_index=True)
                
                outputdic[f"{entity_type} | {entity_name}"] = df
                print(f"Query executed successfully for {entity_type} {entity_name}.")
    except adodbapi.DatabaseError as db_error:
        print(f"Database error for {entity_type} {entity_name}: {db_error}")
    except Exception as e:
        print(f"Unexpected error for {entity_type} {entity_name}: {e}")
    return outputdic

assortmentbrand = {}
# **Threaded Execution**
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = []
    for hierby, hier_values in hierarchy_levels:
        if isinstance(hier_values, list):
            for value in hier_values:
                for area, entity_list in entity_hierarchy:
                    for entity in entity_list:
                            futures.append(executor.submit(execute_dax_query, "Top Brands",entity, area, hierby, value))

    # Wait for all tasks to complete
    for future in futures:
        result=future.result()
        assortmentbrand.update(result)
pd.to_pickle(assortmentbrand, os.path.join(path,"assortmentbybrand.pkl"))

assortmentmanuf = {}
with ThreadPoolExecutor(max_workers=8) as executor:
    futures = []
    for hierby, hier_values in hierarchy_levels:
            if isinstance(hier_values, list):
                for value in hier_values:
                    for area, entity_list in entity_hierarchy:
                        for entity in entity_list:
                            futures.append(executor.submit(execute_dax_query, f"{ManufOrTopC}",entity, area, hierby, value))
    
    # Wait for all tasks to complete
    for future in futures:
        result=future.result()
        assortmentmanuf.update(result)

pd.to_pickle(assortmentmanuf,os.path.join(path,"assortmentbymanuf.pkl"))
# print(f"All DataFrames saved to { r"C:\Users\aleaa\Desktop\New Extraction\assortmentmanuf.pkl"}.")
# Out:
# Query executed successfully for Female Shaving  Hm/Sm.
# Query executed successfully for Female Shaving Rossmann Offline.
# Query executed successfully for Female Shaving Discounter Gesamt.
# Query executed successfully for Female Shaving Drug Stores.
# Query executed successfully for Female Shaving Rossmann Online.
# Query executed successfully for Female Shaving Rossmann.
# Query executed successfully for Female System Discounter Gesamt.
# Query executed successfully for Female System Rossmann.
# Query executed successfully for Female System  Hm/Sm.
# Query executed successfully for Female System Rossmann Offline.
# Query executed successfully for Female System Rossmann Online.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female System Drug Stores.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Razor Discounter Gesamt.
# Query executed successfully for Female Razor Rossmann.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Razor Drug Stores.
# Query executed successfully for Female Razor  Hm/Sm.
# Query executed successfully for Female Razor Rossmann Offline.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Razor Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Unexpected error for  Female Handle Rossmann: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Drug Stores: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Discounter Gesamt: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle  Hm/Sm: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Rossmann Offline: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Rossmann Online: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female Banded Pack Rossmann.
# Query executed successfully for Female Banded Pack Drug Stores.
# Query executed successfully for Female Banded Pack Discounter Gesamt.
# Query executed successfully for Female Banded Pack  Hm/Sm.
# Query executed successfully for Female Banded Pack Rossmann Offline.
# Query executed successfully for Female 1-Blade  Hm/Sm.
# Query executed successfully for Female 1-Blade Rossmann.
# Query executed successfully for Female 1-Blade Discounter Gesamt.
# Query executed successfully for Female Banded Pack Rossmann Online.
# Query executed successfully for Female 1-Blade Rossmann Offline.
# Query executed successfully for Female 1-Blade Drug Stores.
# Query executed successfully for Female 3-Blade Rossmann.
# Query executed successfully for Female 1-Blade Rossmann Online.
# Query executed successfully for Female 3-Blade Discounter Gesamt.
# Query executed successfully for Female 3-Blade  Hm/Sm.
# Query executed successfully for Female 3-Blade Drug Stores.
# Query executed successfully for Female 3-Blade Rossmann Offline.
# Unexpected error for  Female Double Edge Rossmann: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 3-Blade Rossmann Online.
# Unexpected error for  Female Double Edge Discounter Gesamt: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge Rossmann Online: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge Drug Stores: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 6-Blade Rossmann.
# Unexpected error for  Female Double Edge Rossmann Offline: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 6-Blade Discounter Gesamt.
# Unexpected error for  Female Double Edge  Hm/Sm: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 5-Blade Discounter Gesamt.
# Query executed successfully for Female 5-Blade Rossmann.
# Query executed successfully for Female 6-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Drug Stores.
# Query executed successfully for Female 6-Blade Drug Stores.
# Query executed successfully for Female 5-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Rossmann Online.
# Query executed successfully for Female 5-Blade Rossmann Online.
# Query executed successfully for Female 5-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Discounter Gesamt.
# Query executed successfully for Female 2-Blade Rossmann.
# Query executed successfully for Female 2-Blade Drug Stores.
# Query executed successfully for Female 2-Blade  Hm/Sm.
# Query executed successfully for Female 2-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Rossmann.
# Query executed successfully for Female 4-Blade Discounter Gesamt.
# Query executed successfully for Female 4-Blade  Hm/Sm.
# Query executed successfully for Female 4-Blade Drug Stores.
# Query executed successfully for Female 4-Blade Rossmann Offline.
# Query executed successfully for Female 4-Blade Rossmann Online.
# Query executed successfully for Female Shaving Rossmann Offline.
# Query executed successfully for Female Shaving Discounter Gesamt.
# Query executed successfully for Female Shaving Drug Stores.
# Query executed successfully for Female System Discounter Gesamt.
# Query executed successfully for Female System Rossmann.
# Query executed successfully for Female Shaving Rossmann Online.
# Query executed successfully for Female Shaving Rossmann.
# Query executed successfully for Female Shaving  Hm/Sm.
# Query executed successfully for Female System  Hm/Sm.
# Query executed successfully for Female System Drug Stores.
# Query executed successfully for Female System Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female System Rossmann Online.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Razor Rossmann.
# Query executed successfully for Female Razor Discounter Gesamt.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Razor  Hm/Sm.
# Query executed successfully for Female Razor Drug Stores.
# Query executed successfully for Female Razor Rossmann Online.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Razor Rossmann Offline.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Unexpected error for  Female Handle Discounter Gesamt: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Rossmann: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Drug Stores: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle  Hm/Sm: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Rossmann Offline: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Handle Rossmann Online: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female Banded Pack Rossmann.
# Query executed successfully for Female Banded Pack  Hm/Sm.
# Query executed successfully for Female Banded Pack Discounter Gesamt.
# Query executed successfully for Female Banded Pack Drug Stores.
# Query executed successfully for Female Banded Pack Rossmann Offline.
# Query executed successfully for Female Banded Pack Rossmann Online.
# Query executed successfully for Female 1-Blade Rossmann.
# Query executed successfully for Female 1-Blade Discounter Gesamt.
# Query executed successfully for Female 1-Blade  Hm/Sm.
# Query executed successfully for Female 1-Blade Drug Stores.
# Query executed successfully for Female 1-Blade Rossmann Offline.
# Query executed successfully for Female 1-Blade Rossmann Online.
# Query executed successfully for Female 3-Blade Rossmann.
# Query executed successfully for Female 3-Blade Discounter Gesamt.
# Query executed successfully for Female 3-Blade Drug Stores.
# Query executed successfully for Female 3-Blade  Hm/Sm.
# Query executed successfully for Female 3-Blade Rossmann Offline.
# Unexpected error for  Female Double Edge Discounter Gesamt: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 3-Blade Rossmann Online.
# Unexpected error for  Female Double Edge Rossmann: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge Drug Stores: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge  Hm/Sm: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge Rossmann Offline: 3 columns passed, passed data had 1 columns
# Unexpected error for  Female Double Edge Rossmann Online: 3 columns passed, passed data had 1 columns
# Query executed successfully for Female 6-Blade Rossmann.
# Query executed successfully for Female 6-Blade Discounter Gesamt.
# Query executed successfully for Female 6-Blade Drug Stores.
# Query executed successfully for Female 6-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Rossmann Online.
# Query executed successfully for Female 5-Blade  Hm/Sm.
# Query executed successfully for Female 5-Blade Drug Stores.
# Query executed successfully for Female 5-Blade Discounter Gesamt.
# Query executed successfully for Female 5-Blade Rossmann.
# Query executed successfully for Female 6-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Rossmann Online.
# Query executed successfully for Female 2-Blade Rossmann.
# Query executed successfully for Female 2-Blade  Hm/Sm.
# Query executed successfully for Female 2-Blade Discounter Gesamt.
# Query executed successfully for Female 2-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Rossmann.
# Query executed successfully for Female 2-Blade Drug Stores.
# Query executed successfully for Female 4-Blade  Hm/Sm.
# Query executed successfully for Female 4-Blade Drug Stores.
# Query executed successfully for Female 4-Blade Rossmann Offline.
# Query executed successfully for Female 4-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Discounter Gesamt.

# %%
def execute_dax_query_with_retry(BrandorManuf, entity_name, area, hierby, entity_type, retries=3, delay=5):
    """
    Executes a DAX query with retry logic for handling transient errors.
    """
    for attempt in range(retries):
        try:
            outputdic = {}
            dax_query = f"""
            EVALUATE
            CALCULATETABLE(
                SUMMARIZE(
                    Products,
                    Products[{BrandorManuf}],  
                    Products[{prodORitem}],   
                    "Value Share", IF(ISBLANK([Value Share]), 0, [Value Share]),
                    "WD", IF(ISBLANK([WD]), 0, [WD]),
                    "Net Sales", IF(ISBLANK([Net Sales]), 0, [Net Sales]),
                    "Trade Margin %", IF(ISBLANK([Trade Margin %]), 0, [Trade Margin %]),
                    "{prodORitem} Sales Rate", IF(ISBLANK([{prodORitem} Sales Rate]), 0, [{prodORitem} Sales Rate])

                ),
                Products[Category] = "{categories[0]}",
                Products[{hierby}] = "{entity_type}",
                TREATAS(
                    {p12m_dax},
                    Calendar[MonthYear]
                ),
                TREATAS(
                    {{"{entity_name}"}},
                    Market[{area}]
                ),
                FILTER(
                    'Scope', 
                    'Scope'[Scope] = "{hierby}"   
                )
            )   
            """
            with adodbapi.connect(conn_str) as conn:
                conn.timeout = 300  # Increase timeout to 300 seconds
                with conn.cursor() as cursor:
                    cursor.execute(dax_query)
                    columns = [desc[0] for desc in cursor.description]
                    data = cursor.fetchall()
                    
                    df = pd.DataFrame(data, columns=columns)
                    df.columns = df.columns.str.replace(r'.*\[|\]', '', regex=True)
                    df = df.loc[~(df.select_dtypes(include='number') == 0).all(axis=1)]

                    # Add Grand Total row
                    if not df.empty:
                        numeric_cols = df.select_dtypes(include='number').columns

                        # Identify columns containing "price" (case insensitive)
                        price_cols = [col for col in numeric_cols if "price" in col.lower()]
                        sum_cols = [col for col in numeric_cols if col not in price_cols]

                        # Compute the grand total row
                        grand_total_values = {
                            col: df[col].mean() if col in price_cols else df[col].sum() 
                            for col in numeric_cols
                        }

                        # Create a DataFrame row for the grand total
                        grand_total_row = pd.DataFrame(
                            [["Grand Total"] + [grand_total_values.get(col, None) for col in df.columns[1:]]], 
                            columns=df.columns
                        )

                        # Append the Grand Total row to the DataFrame
                        df = pd.concat([df, grand_total_row], ignore_index=True)

                    outputdic[f"{entity_type} | {entity_name}"] = df
                    print(f"Query executed successfully for {entity_type} {entity_name}.")
                    return outputdic
        except adodbapi.DatabaseError as db_error:
            print(f"Attempt {attempt + 1} failed for {entity_type} {entity_name}: {db_error}")
            if attempt < retries - 1:
                time.sleep(delay * (attempt + 1))  # Exponential backoff
            else:
                print(f"Max retries reached for {entity_type} {entity_name}.")
                raise
        except Exception as e:
            print(f"Unexpected error for {entity_type} {entity_name}: {e}")
            raise

def process_entities(BrandorManuf, output_file, max_workers=4):
    """
    Processes entities in parallel and saves the results to a pickle file.
    """

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        future_to_key = {}
        dfs_results = {}
        ordered_keys = []
        result_dict = {}

        for hierby, hier_values in hierarchy_levels:
            if isinstance(hier_values, list):
                for value in hier_values:
                    for area, entity_list in entity_hierarchy:
                        for entity in entity_list:
                                    key = f"{value} | {entity}"
                                    ordered_keys.append(key)
                                    future = executor.submit(
                                        execute_dax_query_with_retry, BrandorManuf, entity, area, hierby, value
                                    )
                                    futures.append(future)
                                    future_to_key[future] = key

                
        
    temp_results = {}
    for future in as_completed(future_to_key):
        key = future_to_key[future]
        try:
            result = future.result()
            temp_results.update(result)
        except Exception as e:
            print(f"Failed to retrieve result for {key}: {e}")

    # Preserve original key order
    for key in ordered_keys:
        if key in temp_results:
            dfs_results[key] = temp_results[key]

    output_file = os.path.join(path, output_file)
    with open(output_file, "wb") as f:
        pd.to_pickle(dfs_results, f)

# Main execution
if __name__ == "__main__":
    # Process Brand or TopB entities
    process_entities(f"{BrandOrTopB}", "assortment.pkl", max_workers=8)

    # Process Manufacturer or TopC entities
    process_entities(f"{ManufOrTopC}", "assortment_manuf.pkl", max_workers=8)
# Out:
# Query executed successfully for Female Shaving  Hm/Sm.
# Query executed successfully for Female Shaving Rossmann Online.
# Query executed successfully for Female Shaving Rossmann.
# Query executed successfully for Female Shaving Discounter Gesamt.
# Query executed successfully for Female Shaving Rossmann Offline.
# Query executed successfully for Female Shaving Drug Stores.
# Query executed successfully for Female System Rossmann.
# Query executed successfully for Female System Discounter Gesamt.
# Query executed successfully for Female System Drug Stores.
# Query executed successfully for Female System Rossmann Offline.
# Query executed successfully for Female System  Hm/Sm.
# Query executed successfully for Female System Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Razor Rossmann.
# Query executed successfully for Female Razor Discounter Gesamt.
# Query executed successfully for Female Razor Drug Stores.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Razor Rossmann Offline.
# Query executed successfully for Female Razor  Hm/Sm.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Razor Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for  Female Handle Rossmann.
# Query executed successfully for  Female Handle Discounter Gesamt.
# Query executed successfully for  Female Handle  Hm/Sm.
# Query executed successfully for  Female Handle Rossmann Offline.
# Query executed successfully for  Female Handle Rossmann Online.
# Query executed successfully for Female Banded Pack Rossmann.
# Query executed successfully for Female Banded Pack Discounter Gesamt.
# Query executed successfully for  Female Handle Drug Stores.
# Query executed successfully for Female Banded Pack Drug Stores.
# Query executed successfully for Female Banded Pack  Hm/Sm.
# Query executed successfully for Female 1-Blade Discounter Gesamt.
# Query executed successfully for Female 1-Blade Drug Stores.
# Query executed successfully for Female Banded Pack Rossmann Online.
# Query executed successfully for Female Banded Pack Rossmann Offline.
# Query executed successfully for Female 1-Blade Rossmann Offline.
# Query executed successfully for Female 1-Blade  Hm/Sm.
# Query executed successfully for Female 1-Blade Rossmann Online.
# Query executed successfully for Female 3-Blade Rossmann.
# Query executed successfully for Female 1-Blade Rossmann.
# Query executed successfully for Female 3-Blade Drug Stores.
# Query executed successfully for Female 3-Blade  Hm/Sm.
# Query executed successfully for Female 3-Blade Discounter Gesamt.
# Query executed successfully for Female 3-Blade Rossmann Offline.
# Query executed successfully for Female 3-Blade Rossmann Online.
# Query executed successfully for  Female Double Edge Rossmann.
# Query executed successfully for  Female Double Edge Discounter Gesamt.
# Query executed successfully for  Female Double Edge Drug Stores.
# Query executed successfully for  Female Double Edge  Hm/Sm.
# Query executed successfully for  Female Double Edge Rossmann Offline.
# Query executed successfully for  Female Double Edge Rossmann Online.
# Query executed successfully for Female 6-Blade Rossmann.
# Query executed successfully for Female 6-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Drug Stores.
# Query executed successfully for Female 6-Blade Discounter Gesamt.
# Query executed successfully for Female 6-Blade Rossmann Offline.
# Query executed successfully for Female 6-Blade Rossmann Online.
# Query executed successfully for Female 5-Blade Discounter Gesamt.
# Query executed successfully for Female 5-Blade Rossmann.
# Query executed successfully for Female 5-Blade  Hm/Sm.
# Query executed successfully for Female 5-Blade Drug Stores.
# Query executed successfully for Female 5-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Rossmann Online.
# Query executed successfully for Female 2-Blade Rossmann.
# Query executed successfully for Female 2-Blade  Hm/Sm.
# Query executed successfully for Female 2-Blade Discounter Gesamt.
# Query executed successfully for Female 2-Blade Drug Stores.
# Query executed successfully for Female 2-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Rossmann.
# Query executed successfully for Female 4-Blade Discounter Gesamt.
# Query executed successfully for Female 4-Blade Drug Stores.
# Query executed successfully for Female 4-Blade  Hm/Sm.
# Query executed successfully for Female 4-Blade Rossmann Offline.
# Query executed successfully for Female 4-Blade Rossmann Online.
# Query executed successfully for Female System Discounter Gesamt.
# Query executed successfully for Female System Rossmann.
# Query executed successfully for Female Shaving  Hm/Sm.
# Query executed successfully for Female Shaving Discounter Gesamt.
# Query executed successfully for Female Shaving Rossmann Offline.
# Query executed successfully for Female Shaving Rossmann.
# Query executed successfully for Female Shaving Rossmann Online.
# Query executed successfully for Female Shaving Drug Stores.
# Query executed successfully for Female System  Hm/Sm.
# Query executed successfully for Female System Drug Stores.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female System Rossmann Online.
# Query executed successfully for Female System Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Razor Discounter Gesamt.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Razor Rossmann.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Razor Drug Stores.
# Query executed successfully for Female Razor  Hm/Sm.
# Query executed successfully for Female Razor Rossmann Offline.
# Query executed successfully for Female Razor Rossmann Online.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for  Female Handle Rossmann.
# Query executed successfully for  Female Handle Discounter Gesamt.
# Query executed successfully for  Female Handle  Hm/Sm.
# Query executed successfully for  Female Handle Drug Stores.
# Query executed successfully for  Female Handle Rossmann Offline.
# Query executed successfully for  Female Handle Rossmann Online.
# Query executed successfully for Female Banded Pack Rossmann.
# Query executed successfully for Female Banded Pack Discounter Gesamt.
# Query executed successfully for Female Banded Pack  Hm/Sm.
# Query executed successfully for Female Banded Pack Drug Stores.
# Query executed successfully for Female Banded Pack Rossmann Offline.
# Query executed successfully for Female Banded Pack Rossmann Online.
# Query executed successfully for Female 1-Blade Rossmann.
# Query executed successfully for Female 1-Blade Discounter Gesamt.
# Query executed successfully for Female 1-Blade Drug Stores.
# Query executed successfully for Female 1-Blade  Hm/Sm.
# Query executed successfully for Female 1-Blade Rossmann Offline.
# Query executed successfully for Female 1-Blade Rossmann Online.
# Query executed successfully for Female 3-Blade Rossmann.
# Query executed successfully for Female 3-Blade Discounter Gesamt.
# Query executed successfully for Female 3-Blade Drug Stores.
# Query executed successfully for Female 3-Blade  Hm/Sm.
# Query executed successfully for Female 3-Blade Rossmann Offline.
# Query executed successfully for Female 3-Blade Rossmann Online.
# Query executed successfully for  Female Double Edge Rossmann.
# Query executed successfully for  Female Double Edge Discounter Gesamt.
# Query executed successfully for  Female Double Edge  Hm/Sm.
# Query executed successfully for  Female Double Edge Drug Stores.
# Query executed successfully for  Female Double Edge Rossmann Online.
# Query executed successfully for  Female Double Edge Rossmann Offline.
# Query executed successfully for Female 6-Blade Discounter Gesamt.
# Query executed successfully for Female 6-Blade Rossmann Online.
# Query executed successfully for Female 6-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Rossmann.
# Query executed successfully for Female 5-Blade Rossmann.
# Query executed successfully for Female 5-Blade Discounter Gesamt.
# Query executed successfully for Female 5-Blade  Hm/Sm.
# Query executed successfully for Female 5-Blade Drug Stores.
# Query executed successfully for Female 6-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Rossmann Offline.
# Query executed successfully for Female 5-Blade Rossmann Online.
# Query executed successfully for Female 2-Blade Discounter Gesamt.
# Query executed successfully for Female 2-Blade Rossmann.
# Query executed successfully for Female 2-Blade  Hm/Sm.
# Query executed successfully for Female 2-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Drug Stores.
# Query executed successfully for Female 2-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Rossmann.
# Query executed successfully for Female 4-Blade Drug Stores.
# Query executed successfully for Female 4-Blade Discounter Gesamt.
# Query executed successfully for Female 4-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Drug Stores.
# Query executed successfully for Female 4-Blade Rossmann Offline.
# Query executed successfully for Female 4-Blade Rossmann Online.

# %%
def execute_dax_query_with_retry(entity_name, area, hierby, entity_type, retries=3, delay=5):
    for attempt in range(retries):
        try:
            outputdic = {}
            dax_query = f"""
            EVALUATE
            CALCULATETABLE(
                SUMMARIZE(
                    Products,
                    Products[{prodORitem}],   
                    "Value Share", IF(ISBLANK([Value Share]), 0, [Value Share])
                ),
                Products[{hierby}] = "{entity_type}",
                TREATAS(
                    {p12m_dax},
                    Calendar[MonthYear]
                ),
                TREATAS(
                    {{"{entity_name}"}},
                    Market[{area}]
                ),
                FILTER(
                    'Scope', 
                    'Scope'[Scope] = "{hierby}"   
                )
            )   
            """
            with adodbapi.connect(conn_str) as conn:
                conn.timeout = 300  # Set connection timeout
                with conn.cursor() as cursor:
                    cursor.execute(dax_query)
                    columns = [desc[0] for desc in cursor.description]
                    data = cursor.fetchall()
                    
                    df = pd.DataFrame(data, columns=columns)
                    df.columns = df.columns.str.replace(r'.*\[|\]', '', regex=True)
                    df = df.loc[~(df.select_dtypes(include='number') == 0).all(axis=1)]

                    # Add Grand Total row
                    if not df.empty:
                        df = df.sort_values(by="Value Share", ascending=False).reset_index(drop=True)
                        df[f"Cumulative {prodORitem} Share"] = df["Value Share"].cumsum()
                    outputdic[f"{entity_type} | {entity_name}"] = df
                    print(f"Query executed successfully for {entity_type} {entity_name}.")
                    return outputdic
        except adodbapi.DatabaseError as db_error:
            print(f"Attempt {attempt + 1} failed for {entity_type} {entity_name}: {db_error}")
            if attempt < retries - 1:
                time.sleep(delay)  # Wait before retrying
            else:
                print(f"Max retries reached for {entity_type} {entity_name}.")
                raise
        except Exception as e:
            print(f"Unexpected error for {entity_type} {entity_name}: {e}")
            raise

# List of all entities to process
# Threaded execution
cumulative_share = {}
dfs_results = {}
ordered_keys = []
futures = []

with ThreadPoolExecutor(max_workers=8) as executor:
    future_to_key = {}

    for hierby, hier_values in hierarchy_levels:
        if isinstance(hier_values, list):
            for value in hier_values:
                for area, entity_list in entity_hierarchy:
                    for entity in entity_list:
                        key = f"{value} | {entity}"
                        ordered_keys.append(key)
                        future = executor.submit(execute_dax_query_with_retry, entity, area, hierby, value)
                        future_to_key[future] = key

    temp_results = {}
    for future in as_completed(future_to_key):
        key = future_to_key[future]
        try:
            result = future.result()
            temp_results.update(result)
        except Exception as e:
            print(f"Failed to retrieve result for {key}: {e}")

# Preserve original key order
for key in ordered_keys:
    if key in temp_results:
        dfs_results[key] = temp_results[key]

output_file = os.path.join(path, "cumulative_share.pkl")
with open(output_file, "wb") as f:
    pd.to_pickle(dfs_results, f)

print(f"All DataFrames saved to {output_file}.")
# Out:
# Query executed successfully for Female Shaving Discounter Gesamt.
# Query executed successfully for Female Shaving Drug Stores.
# Query executed successfully for Female Shaving Rossmann Offline.
# Query executed successfully for Female System Discounter Gesamt.
# Query executed successfully for Female Shaving Rossmann.
# Query executed successfully for Female Shaving  Hm/Sm.
# Query executed successfully for Female System Rossmann.
# Query executed successfully for Female System Drug Stores.Query executed successfully for Female System Rossmann Offline.
#
# Query executed successfully for Female System Rossmann Online.
# Query executed successfully for Female Shaving Rossmann Online.
# Query executed successfully for Female System  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for Female Razor Rossmann.
# Query executed successfully for Female Razor Discounter Gesamt.
# Query executed successfully for Female Razor Drug Stores.
# Query executed successfully for Female Razor Rossmann Offline.
# Query executed successfully for Female Razor  Hm/Sm.
# Query executed successfully for Female Razor Rossmann Online.
# Query executed successfully for Female Blades Rossmann.
# Query executed successfully for Female Blades Discounter Gesamt.
# Query executed successfully for Female Blades Drug Stores.
# Query executed successfully for Female Blades  Hm/Sm.
# Query executed successfully for Female Blades Rossmann Offline.
# Query executed successfully for Female Blades Rossmann Online.
# Query executed successfully for Female Dispo Rossmann.
# Query executed successfully for Female Dispo  Hm/Sm.
# Query executed successfully for Female Dispo Discounter Gesamt.
# Query executed successfully for Female Dispo Drug Stores.
# Query executed successfully for Female Dispo Rossmann Offline.
# Query executed successfully for Female Dispo Rossmann Online.
# Query executed successfully for  Female Handle Rossmann.
# Query executed successfully for  Female Handle Discounter Gesamt.
# Query executed successfully for  Female Handle Drug Stores.
# Query executed successfully for  Female Handle Rossmann Offline.
# Query executed successfully for  Female Handle  Hm/Sm.
# Query executed successfully for  Female Handle Rossmann Online.
# Query executed successfully for Female Banded Pack Rossmann.
# Query executed successfully for Female Banded Pack Discounter Gesamt.
# Query executed successfully for Female Banded Pack  Hm/Sm.
# Query executed successfully for Female Banded Pack Drug Stores.
# Query executed successfully for Female Banded Pack Rossmann Online.
# Query executed successfully for Female 1-Blade Rossmann.
# Query executed successfully for Female Banded Pack Rossmann Offline.
# Query executed successfully for Female 1-Blade Discounter Gesamt.
# Query executed successfully for Female 1-Blade Drug Stores.
# Query executed successfully for Female 1-Blade  Hm/Sm.
# Query executed successfully for Female 1-Blade Rossmann Offline.
# Query executed successfully for Female 1-Blade Rossmann Online.
# Query executed successfully for Female 3-Blade Rossmann.
# Query executed successfully for Female 3-Blade  Hm/Sm.
# Query executed successfully for Female 3-Blade Drug Stores.
# Query executed successfully for Female 3-Blade Discounter Gesamt.
# Query executed successfully for Female 3-Blade Rossmann Offline.
# Query executed successfully for Female 3-Blade Rossmann Online.
# Query executed successfully for  Female Double Edge Rossmann.
# Query executed successfully for  Female Double Edge Discounter Gesamt.
# Query executed successfully for  Female Double Edge Drug Stores.
# Query executed successfully for  Female Double Edge  Hm/Sm.
# Query executed successfully for  Female Double Edge Rossmann Offline.
# Query executed successfully for  Female Double Edge Rossmann Online.
# Query executed successfully for Female 6-Blade Rossmann.
# Query executed successfully for Female 6-Blade Discounter Gesamt.
# Query executed successfully for Female 6-Blade Drug Stores.
# Query executed successfully for Female 6-Blade  Hm/Sm.
# Query executed successfully for Female 6-Blade Rossmann Offline.
# Query executed successfully for Female 6-Blade Rossmann Online.
# Query executed successfully for Female 5-Blade Rossmann.
# Query executed successfully for Female 5-Blade Discounter Gesamt.
# Query executed successfully for Female 5-Blade  Hm/Sm.Query executed successfully for Female 5-Blade Drug Stores.
#
# Query executed successfully for Female 5-Blade Rossmann Offline.
# Query executed successfully for Female 2-Blade Rossmann.
# Query executed successfully for Female 5-Blade Rossmann Online.
# Query executed successfully for Female 2-Blade Discounter Gesamt.
# Query executed successfully for Female 2-Blade  Hm/Sm.
# Query executed successfully for Female 2-Blade Drug Stores.
# Query executed successfully for Female 2-Blade Rossmann Online.
# Query executed successfully for Female 2-Blade Rossmann Offline.
# Query executed successfully for Female 4-Blade Rossmann.
# Query executed successfully for Female 4-Blade  Hm/Sm.
# Query executed successfully for Female 4-Blade Drug Stores.
# Query executed successfully for Female 4-Blade Discounter Gesamt.
# Query executed successfully for Female 4-Blade Rossmann Online.
# Query executed successfully for Female 4-Blade Rossmann Offline.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\cumulative_share.pkl.

# %%
def execute_dax_query(entity_name, area, hierby, brand=None, manuf=None):
    outputdic = {}
    manuf_filter = f'Products[{ManufOrTopC}]="{manuf}"' if manuf else ""
    brand_filter = f'Products[{BrandOrTopB}]="{brand}", Products[{ManufOrTopC}]="{client_manuf[0]}"' if brand else ""
    # Construct filter condition dynamically
    filters = ", ".join(filter(None, [manuf_filter, brand_filter, f'Products[Category] = "{categories[0]}"']))
    key = f"{brand} | {entity_name}" if brand else f"{manuf} | {entity_name}" if manuf else f"{entity_name}"
 
    dax_query = f"""
    EVALUATE
    CALCULATETABLE(
        SUMMARIZE(
            Products,
            Products[{hierby}],  
            "Av No SKUs", IF(ISBLANK([Av No SKUs]), 0, [Av No SKUs]),
            "SKU Share", IF(ISBLANK([SKU Share]), 0, [SKU Share]),
            "Value Share", IF(ISBLANK([Value Share]), 0, [Value Share])
        ),
        {filters},
        TREATAS(
            {p12m_dax},
            Calendar[MonthYear]
        ),
        TREATAS(
            {{"{entity_name}"}},
            Market[{area}]
        ),
        FILTER(
            'Scope',
            'Scope'[Scope] = "Category"  
        )
    )  
    """
 
    try:
        with adodbapi.connect(conn_str) as conn:
            with conn.cursor() as cursor:
                cursor.execute(dax_query)
                columns = [desc[0] for desc in cursor.description]
                data = cursor.fetchall()
 
                df = pd.DataFrame(data, columns=columns)
                df.columns = df.columns.str.replace(r'.*\[|\]', '', regex=True)
                df = df.loc[~(df.select_dtypes(include='number') == 0).all(axis=1)]
 
                if not df.empty:
                    numeric_cols = df.select_dtypes(include='number').columns
                    total_values = {}
 
                    for col in numeric_cols:
                        if "price" in col.lower():  # Check if the column name contains "price" (case insensitive)
                            total_values[col] = df[col].mean()  # Take the average
                        else:
                            total_values[col] = df[col].sum()  # Take the sum
 
                    grand_total_row = pd.DataFrame([["Grand Total"] + [total_values.get(col, " ") for col in df.columns[1:]]], columns=df.columns)
                    df = pd.concat([df, grand_total_row], ignore_index=True)
                outputdic[key] = df
                print(f"Query executed successfully for {entity_name}.")
    except adodbapi.DatabaseError as db_error:
        print(f"Database error for {entity_name}: {db_error}")
    except Exception as e:
        print(f"Unexpected error for {entity_name}: {e}")
   
    return outputdic
 
# Process data concurrently
def process_dax_queries(hierarchy_levels, entity_hierarchy, client_brands=None, client_manuf=None):
    with ThreadPoolExecutor(max_workers=8) as executor:
        for hierby, hier_values in hierarchy_levels:
            if hierby == "Category":
                continue
           
            dfs_results = {}
            futures = []
           
            for area, entity_list in entity_hierarchy:
                for entity in entity_list:
                    if client_brands:
                        for brand in client_brands:
                            futures.append(executor.submit(execute_dax_query, entity, area, hierby, brand=brand))
                    elif client_manuf:
                        for manuf in client_manuf:
                            futures.append(executor.submit(execute_dax_query, entity, area, hierby, manuf=manuf))
                    else:
                        futures.append(executor.submit(execute_dax_query, entity, area, hierby))
 
            for future in as_completed(futures):
                result = future.result()
                dfs_results.update(result)
 
            # Determine output type
            output_type = "brands" if client_brands else ("manuf" if client_manuf else "total")
 
            # Save results
            output_path = rf"{path}\{hierby}_dfs_{output_type}.pkl"
            pd.to_pickle(dfs_results, output_path)
            print(f"All DataFrames saved to {output_path}.")
 
# Run the processing function for different levels
process_dax_queries(hierarchy_levels, entity_hierarchy)  # Total-level
process_dax_queries(hierarchy_levels, entity_hierarchy, client_brands=client_brands)  # Brand-level
process_dax_queries(hierarchy_levels, entity_hierarchy, client_manuf=client_manuf)  # Manufacturer-leve
# Out:
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Sector_dfs_total.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Segment_dfs_total.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubSegment_dfs_total.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubCategory_dfs_total.pkl.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Rossmann Online.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Sector_dfs_brands.pkl.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Rossmann Online.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Segment_dfs_brands.pkl.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Rossmann Online.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubSegment_dfs_brands.pkl.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubCategory_dfs_brands.pkl.
# Query executed successfully for Drug Stores.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Rossmann Offline.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Sector_dfs_manuf.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Drug Stores.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Rossmann.
# Query executed successfully for Rossmann Offline.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\Segment_dfs_manuf.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann Online.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Rossmann.
# Query executed successfully for Rossmann Offline.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubSegment_dfs_manuf.pkl.
# Query executed successfully for  Hm/Sm.
# Query executed successfully for Rossmann Offline.
# Query executed successfully for Drug Stores.
# Query executed successfully for Rossmann.
# Query executed successfully for Discounter Gesamt.
# Query executed successfully for Rossmann Online.
# All DataFrames saved to c:\Users\Ali Salem\Desktop\App_Update\Assortment\Assortment Datasets Test\SubCategory_dfs_manuf.pkl.

# %%
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Script started at: {time.ctime(start_time)}")
print(f"Script ended at: {time.ctime(end_time)}")
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Script started at: Tue Aug 19 13:13:50 2025
# Script ended at: Tue Aug 19 13:19:25 2025
# Elapsed time: 334.84 seconds

# %%
loaded_data = {}
datasets_path =os.getcwd()+"\\Assortment Datasets Test\\"
datasets = os.listdir(datasets_path)
for d in datasets:
    with open(datasets_path+d, 'rb') as handle:
        globals()[d.split('.')[0]] = pd.read_pickle(handle)
